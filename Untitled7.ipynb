# %% [markdown]
# <a href="https://colab.research.google.com/github/eztariylse/proposal/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import  numpy as np
import csv
dfdel = pd.read_csv('delitos_final.csv', low_memory = False )
dfdel
#1) Analisis exploratorio
dfdel
# Out:
#         a_hechos mes_hechos  ...   longitud      latitud
# 0         2016.0      Enero  ... -99.103527    19.481076
# 1         2017.0  Noviembre  ...        NaN          NaN
# 2         2017.0  Noviembre  ... -99.106072  19.39539767
# 3         2015.0  Diciembre  ... -99.055887    19.322458
# 4         2018.0       Mayo  ... -99.042786  19.31914051
# ...          ...        ...  ...        ...          ...
# 808866    2018.0      Julio  ... -99.182018  19.43941801
# 808867    2018.0      Julio  ... -99.134738   19.2549355
# 808868    2019.0    Febrero  ... -99.122943   19.4738668
# 808869    2019.0    Febrero  ... -99.163384  19.47359307
# 808870    2017.0      Abril  ... -99.083974  19.43515304
#
# [808871 rows x 17 columns]

# %% [markdown]
# #1) Realizar un análisis exploratorio y descriptivo de los años 2016 al 2019 identificar

# %% [markdown]
# #2)Encontrar el año mas delictivo

# %% [markdown]
# #¿Cuál ha sido la tasa de crecimiento del Robo a pasajero en los últimos tres años?
# El rank mostrado a continuacion  es con  base calculo incluido por cada cien mil habitantes por cada alcaldía :
#
# Fórmula de cálculo:
#
# T = (NT)/(PT) *100,000
#
# Donde:
#
# T: es la tasa por 100 mil habitantes.
#
# NT: es el número total de eventos de interés.
#
# PT: es la población total a mitad de periodo.
#
# Tomando en cuenta los registros de censo del INEGI de poblacion 2015  por cada municipio de acuerdo a al total  de delitos registrados por cada año se puede ver lo siguiente:[Rank de delitos por alcaldia por cada cien mil habitantes]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #¿Las tres alcaldías con mayor índice delictivo?
